# %% [markdown]
# # Merging existing knowledge base with new papers

# %%
# Likely can just run after double checking the paths

import pandas as pd
import json

# Load in existing knowledge base from papers
papers_json_path = 'papers/latest_papers.json'

# Load in potentially new data from data_collection folder
new_data_json_path = '../data_collection/openalex/latest_unique_papers_downloaded.json'

# load the data from your JSON file
with open(papers_json_path, 'r') as f:
    data = json.load(f)

# convert the data into a pandas DataFrame
existing_df = pd.DataFrame(data)

# print out the DataFrame to verify
print(existing_df.head())

# load the data from your JSON file
with open(new_data_json_path, 'r') as f:
    new_data = json.load(f)

# convert the data into a pandas DataFrame
new_df = pd.DataFrame(new_data)

# print out the DataFrame to verify
print(new_df.head())
# Out:
#                                  id  \
# 0  https://openalex.org/W1002897494
# 1  https://openalex.org/W1010274275
# 2  https://openalex.org/W1012054217
# 3   https://openalex.org/W101897731
# 4  https://openalex.org/W1023696101
#
#                                             abstract  \
# 0  Abstract Carbon Capture and Storage is develop...
# 1  Searching for efficient solid sorbents for CO2...
# 2  The gaseous carbon dioxide incorporation react...
# 3                                               None
# 4  This paper presents a model to perform energy ...
#
#                                              authors  citationCount  \
# 0  [[https://openalex.org/A5054450376, Yasin Ghol...           10.0
# 1  [[https://openalex.org/A5005055697, Guoping Ga...           38.0
# 2  [[https://openalex.org/A5044055674, Chika Haya...           21.0
# 3  [[https://openalex.org/A5030437606, Teng Ben],...            1.0
# 4  [[https://openalex.org/A5067189491, Arun Verma...           20.0
#
#    citationCount_normalized  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                            citations  \
# 0  [https://openalex.org/W1753239825, https://ope...
# 1  [https://openalex.org/W1966750682, https://ope...
# 2  [https://openalex.org/W1973556473, https://ope...
# 3  [https://openalex.org/W656376090, https://open...
# 4  [https://openalex.org/W1965513514, https://ope...
#
#                                   classification_ids  \
# 0  [[numerical pressure-decay method, 4.1, 0.77],...
# 1  [[CO2 adsorption, 2.9, 0.81], [separation, 4.2...
# 2  [[Cobalt-Catalyzed Reductive Carboxylation, 10...
# 3  [[Carbon Dioxide Capture, 2.1, 0.79], [Porous ...
# 4  [[process simulation model, 10.1, 0.63], [ener...
#
#                                             concepts  \
# 0  [{'id': 'https://openalex.org/C10899652', 'wik...
# 1  [{'id': 'https://openalex.org/C162862793', 'wi...
# 2  [{'id': 'https://openalex.org/C185592680', 'wi...
# 3  [{'id': 'https://openalex.org/C150394285', 'wi...
# 4  [{'id': 'https://openalex.org/C194439259', 'wi...
#
#                                                doi  \
# 0     https://doi.org/10.1016/j.molliq.2015.06.060
# 1  https://doi.org/10.1016/j.commatsci.2015.06.005
# 2            https://doi.org/10.1246/bcsj.20150043
# 3      https://doi.org/10.1007/978-3-642-54646-4_4
# 4   https://doi.org/10.1016/j.ijhydene.2015.06.149
#
#                                            embedding  ...  \
# 0  [-0.4225695729255676, 0.062300171703100204, 0....  ...
# 1  [-0.8119574189186096, -0.12326264381408691, 0....  ...
# 2  [-0.905866265296936, -0.24191510677337646, 1.2...  ...
# 3  [-0.048764150589704514, -0.2366003841161728, 0...  ...
# 4  [-0.13096152245998383, 0.1287851482629776, 1.0...  ...
#
#                             paperId publication_date relevance_score  \
# 0  https://openalex.org/W1002897494       2015-11-01       21.742895
# 1  https://openalex.org/W1010274275       2015-10-01       21.940535
# 2  https://openalex.org/W1012054217       2015-06-15       21.467160
# 3   https://openalex.org/W101897731       2014-01-01       22.707438
# 4  https://openalex.org/W1023696101       2015-09-01       17.861244
#
#                     search_score  \
# 0  [[carbon capture, 21.742895]]
# 1  [[carbon capture, 21.940535]]
# 2   [[carbon capture, 21.46716]]
# 3  [[carbon capture, 22.707438]]
# 4  [[carbon capture, 17.861244]]
#
#                                                 text  \
# 0  Title: Suggesting a numerical pressure-decay m...
# 1  Title: Modelling CO 2 adsorption and separatio...
# 2  Title: Cobalt-Catalyzed Reductive Carboxylatio...
# 3  Title: Carbon Dioxide Capture in Porous Aromat...
# 4  Title: Development of a process simulation mod...
#
#                                                title  \
# 0  Suggesting a numerical pressure-decay method f...
# 1  Modelling CO 2 adsorption and separation on ex...
# 2  Cobalt-Catalyzed Reductive Carboxylation of α,...
# 3  Carbon Dioxide Capture in Porous Aromatic Fram...
# 4  Development of a process simulation model for ...
#
#                                                url          x          y  \
# 0     https://doi.org/10.1016/j.molliq.2015.06.060 -42.265751   4.114934
# 1  https://doi.org/10.1016/j.commatsci.2015.06.005 -15.913016  -9.927729
# 2            https://doi.org/10.1246/bcsj.20150043 -12.920057  -1.328741
# 3      https://doi.org/10.1007/978-3-642-54646-4_4  -9.399205 -15.376349
# 4   https://doi.org/10.1016/j.ijhydene.2015.06.149 -38.810551 -24.716375
#
#      year
# 0  2015.0
# 1  2015.0
# 2  2015.0
# 3  2014.0
# 4  2015.0
#
# [5 rows x 23 columns]
#                                  id                                    doi  \
# 0  https://openalex.org/W2075019608  https://doi.org/10.1104/pp.109.136549
#
#                                                title  isOpenAccess  \
# 0  A Dynamic Interface for Capsaicinoid Systems B...          True
#
#                                             abstract  \
# 0  Abstract Capsaicinoids are the pungent alkaloi...
#
#                             paperId                                    url  \
# 0  https://openalex.org/W2075019608  https://doi.org/10.1104/pp.109.136549
#
#                                            citations  citationCount  \
# 0  [https://openalex.org/W945153742, https://open...            130
#
#                                             concepts publication_date  \
# 0  [{'id': 'https://openalex.org/C86803240', 'wik...       2009-06-24
#
#    relevance_score language  year  \
# 0        21.730337       en  2009
#
#                                         search_score  \
# 0  [[Enoyl-CoA carboxylase/reductase enzymes, 21....
#
#                                              authors
# 0  [[https://openalex.org/A5084403759, Michael Ma...

# %%
print(existing_df.columns)
# Out:
# Index(['id', 'abstract', 'authors', 'citationCount',
#        'citationCount_normalized', 'citations', 'classification_ids',
#        'concepts', 'doi', 'embedding', 'isOpenAccess',
#        'keyword_classification_ids', 'language', 'paperId', 'publication_date',
#        'relevance_score', 'search_score', 'text', 'title', 'url', 'x', 'y',
#        'year'],
#       dtype='object')

# %%
print(new_df.columns)
# new_df.iloc[124]
# Out:
# Index(['id', 'doi', 'title', 'isOpenAccess', 'abstract', 'paperId', 'url',
#        'citations', 'citationCount', 'concepts', 'publication_date',
#        'relevance_score', 'language', 'year', 'search_score', 'authors'],
#       dtype='object')

# %%
# Set 'id' as the index in both dataframes if not done already
existing_df.set_index('id', inplace=True)
new_df.set_index('id', inplace=True)

# Combine the two dataframes, updating the values in existing_df with the non-NA ones from new_df and adding new rows from new_df
combined_df = new_df.combine_first(existing_df)

# Reset the index
combined_df.reset_index(inplace=True)

# %%
combined_df[combined_df["embedding"].notnull()].head(10)
# Out:
#                                  id  \
# 0  https://openalex.org/W1002897494
# 1  https://openalex.org/W1010274275
# 2  https://openalex.org/W1012054217
# 3   https://openalex.org/W101897731
# 4  https://openalex.org/W1023696101
# 5  https://openalex.org/W1028462910
# 6   https://openalex.org/W103632297
# 7   https://openalex.org/W105069333
# 8  https://openalex.org/W1062343535
# 9   https://openalex.org/W106711868
#
#                                             abstract  \
# 0  Abstract Carbon Capture and Storage is develop...
# 1  Searching for efficient solid sorbents for CO2...
# 2  The gaseous carbon dioxide incorporation react...
# 3                                               None
# 4  This paper presents a model to perform energy ...
# 5  In a pulp mill the energy conversion mainly ta...
# 6  Continuing support for combustion research is ...
# 7  The Role of Law in Responding to Climate Chang...
# 8  Existing monitoring protocols for the storage ...
# 9  This article outlines the ongoing research, de...
#
#                                              authors  citationCount  \
# 0  [[https://openalex.org/A5054450376, Yasin Ghol...           10.0
# 1  [[https://openalex.org/A5005055697, Guoping Ga...           38.0
# 2  [[https://openalex.org/A5044055674, Chika Haya...           21.0
# 3  [[https://openalex.org/A5030437606, Teng Ben],...            1.0
# 4  [[https://openalex.org/A5067189491, Arun Verma...           20.0
# 5  [[https://openalex.org/A5003756798, Erik Hekto...            1.0
# 6  [[https://openalex.org/A2072231077, Robert W. ...            7.0
# 7  [[https://openalex.org/A5080990487, Nicola Dur...            7.0
# 8  [[https://openalex.org/A5042943033, Tim Dixon]...           38.0
# 9                                               None         1948.0
#
#    citationCount_normalized  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# 5                       NaN
# 6                       NaN
# 7                       NaN
# 8                       NaN
# 9                  7.246559
#
#                                            citations  \
# 0  [https://openalex.org/W1753239825, https://ope...
# 1  [https://openalex.org/W1966750682, https://ope...
# 2  [https://openalex.org/W1973556473, https://ope...
# 3  [https://openalex.org/W656376090, https://open...
# 4  [https://openalex.org/W1965513514, https://ope...
# 5  [https://openalex.org/W1965871315, https://ope...
# 6  [https://openalex.org/W1592130436, https://ope...
# 7                                                 []
# 8  [https://openalex.org/W1501420375, https://ope...
# 9  https://api.openalex.org/works?filter=cites:W1...
#
#                                   classification_ids  \
# 0  [[numerical pressure-decay method, 4.1, 0.77],...
# 1  [[CO2 adsorption, 2.9, 0.81], [separation, 4.2...
# 2  [[Cobalt-Catalyzed Reductive Carboxylation, 10...
# 3  [[Carbon Dioxide Capture, 2.1, 0.79], [Porous ...
# 4  [[process simulation model, 10.1, 0.63], [ener...
# 5  [[Carbon Dioxide Capture, 2.1, 0.79], [Pulp an...
# 6  [[Combustion Technology, 2.1, 0.83], [fossil f...
# 7  [[Legal Responses, 7.1, 0.81], [Climate Change...
# 8  [[monitoring protocols, 8.1, 0.94], [CO2 geolo...
# 9  [[Microgrids, 6.4, 0.84], [distributed generat...
#
#                                             concepts  \
# 0  [{'id': 'https://openalex.org/C10899652', 'wik...
# 1  [{'id': 'https://openalex.org/C162862793', 'wi...
# 2  [{'id': 'https://openalex.org/C185592680', 'wi...
# 3  [{'id': 'https://openalex.org/C150394285', 'wi...
# 4  [{'id': 'https://openalex.org/C194439259', 'wi...
# 5  [{'id': 'https://openalex.org/C2781110116', 'w...
# 6  [{'id': 'https://openalex.org/C105923489', 'wi...
# 7  [{'id': 'https://openalex.org/C132651083', 'wi...
# 8  [{'id': 'https://openalex.org/C47737302', 'wik...
# 9  [{'id': 'https://openalex.org/C2776784348', 'w...
#
#                                                doi  \
# 0     https://doi.org/10.1016/j.molliq.2015.06.060
# 1  https://doi.org/10.1016/j.commatsci.2015.06.005
# 2            https://doi.org/10.1246/bcsj.20150043
# 3      https://doi.org/10.1007/978-3-642-54646-4_4
# 4   https://doi.org/10.1016/j.ijhydene.2015.06.149
# 5                                             None
# 6      https://doi.org/10.1007/978-94-007-0412-1_1
# 7                                             None
# 8      https://doi.org/10.1016/j.ijggc.2015.05.029
# 9         https://doi.org/10.1109/mpae.2007.376583
#
#                                            embedding  ...  \
# 0  [-0.4225695729255676, 0.062300171703100204, 0....  ...
# 1  [-0.8119574189186096, -0.12326264381408691, 0....  ...
# 2  [-0.905866265296936, -0.24191510677337646, 1.2...  ...
# 3  [-0.048764150589704514, -0.2366003841161728, 0...  ...
# 4  [-0.13096152245998383, 0.1287851482629776, 1.0...  ...
# 5  [-0.0863686352968216, 0.4754101037979126, 1.08...  ...
# 6  [-0.531643807888031, 0.23009800910949707, 0.61...  ...
# 7  [-0.7133026719093323, -0.11468589305877686, 0....  ...
# 8  [-0.49119389057159424, 0.06770742684602737, 0....  ...
# 9  [0.014594187028706074, 0.030436156317591667, 0...  ...
#
#                             paperId publication_date relevance_score  \
# 0  https://openalex.org/W1002897494       2015-11-01       21.742895
# 1  https://openalex.org/W1010274275       2015-10-01       21.940535
# 2  https://openalex.org/W1012054217       2015-06-15       21.467160
# 3   https://openalex.org/W101897731       2014-01-01       22.707438
# 4  https://openalex.org/W1023696101       2015-09-01       17.861244
# 5  https://openalex.org/W1028462910       2005-01-01       23.888971
# 6   https://openalex.org/W103632297       2011-01-01       22.008118
# 7   https://openalex.org/W105069333       2011-01-04       18.517447
# 8  https://openalex.org/W1062343535       2015-10-01       17.489640
# 9   https://openalex.org/W106711868             None             NaN
#
#                     search_score  \
# 0  [[carbon capture, 21.742895]]
# 1  [[carbon capture, 21.940535]]
# 2   [[carbon capture, 21.46716]]
# 3  [[carbon capture, 22.707438]]
# 4  [[carbon capture, 17.861244]]
# 5  [[carbon capture, 23.888971]]
# 6  [[carbon capture, 22.008118]]
# 7  [[carbon capture, 18.517447]]
# 8   [[carbon capture, 17.48964]]
# 9                           None
#
#                                                 text  \
# 0  Title: Suggesting a numerical pressure-decay m...
# 1  Title: Modelling CO 2 adsorption and separatio...
# 2  Title: Cobalt-Catalyzed Reductive Carboxylatio...
# 3  Title: Carbon Dioxide Capture in Porous Aromat...
# 4  Title: Development of a process simulation mod...
# 5  Title: Carbon Dioxide Capture in the Pulp and ...
# 6  Title: The Role of Combustion Technology in th...
# 7  Title: Legal Responses to Climate Change. Abst...
# 8  Title: Improving monitoring protocols for CO2 ...
# 9  Title: Microgrids. Abstract: This article outl...
#
#                                                title  \
# 0  Suggesting a numerical pressure-decay method f...
# 1  Modelling CO 2 adsorption and separation on ex...
# 2  Cobalt-Catalyzed Reductive Carboxylation of α,...
# 3  Carbon Dioxide Capture in Porous Aromatic Fram...
# 4  Development of a process simulation model for ...
# 5  Carbon Dioxide Capture in the Pulp and Paper I...
# 6  The Role of Combustion Technology in the 21st ...
# 7                  Legal Responses to Climate Change
# 8  Improving monitoring protocols for CO2 geologi...
# 9                                         Microgrids
#
#                                                 url          x          y  \
# 0      https://doi.org/10.1016/j.molliq.2015.06.060 -42.265751   4.114934
# 1   https://doi.org/10.1016/j.commatsci.2015.06.005 -15.913016  -9.927729
# 2             https://doi.org/10.1246/bcsj.20150043 -12.920057  -1.328741
# 3       https://doi.org/10.1007/978-3-642-54646-4_4  -9.399205 -15.376349
# 4    https://doi.org/10.1016/j.ijhydene.2015.06.149 -38.810551 -24.716375
# 5  https://research.chalmers.se/en/publication/9920 -39.621006 -26.748983
# 6       https://doi.org/10.1007/978-94-007-0412-1_1 -59.983696  -6.735415
# 7               http://ci.nii.ac.jp/ncid/BB07622906 -62.529289 -10.624932
# 8       https://doi.org/10.1016/j.ijggc.2015.05.029 -54.125225  -4.230964
# 9          https://doi.org/10.1109/mpae.2007.376583 -53.935482 -20.382832
#
#      year
# 0  2015.0
# 1  2015.0
# 2  2015.0
# 3  2014.0
# 4  2015.0
# 5  2005.0
# 6  2011.0
# 7  2011.0
# 8  2015.0
# 9  2007.0
#
# [10 rows x 23 columns]

# %%
from datetime import datetime
import os

now = datetime.now()
date_str = now.strftime('%y-%m-%d')
time_str = now.strftime('%H-%M-%S')
if not os.path.exists(f'papers/{date_str}'):
    os.makedirs(f'papers/{date_str}')

combined_df.to_json(f'papers/{date_str}/{time_str}_{combined_df.shape[0]}_database_update.json', orient='records')

combined_df.to_json(f'papers/{date_str}/{time_str}_{combined_df.shape[0]}_database_update_readable.json', orient='records', indent=2)

# %%
# Update the main knowledge base file that will be saved over Github
combined_df.to_json(f'papers/latest_papers.json', orient='records')
