# %% [markdown]
# # Merging existing knowledge base with new papers

# %%
import pandas as pd
import json

# Load in existing knowledge base from papers
papers_json_path = r'C:\Users\1kevi\Desktop\projects\Research\autoscious-carbon-capture\knowledge_base\papers\23-07-25_11755_database_update.json'

# Load in potentially new data from data_collection folder
new_data_json_path = r'C:\Users\1kevi\Desktop\projects\Research\autoscious-carbon-capture\data_collection\openalex\23-07-25\extracted_output_relevance_180.json'

# load the data from your JSON file
with open(papers_json_path, 'r') as f:
    data = json.load(f)

# convert the data into a pandas DataFrame
existing_df = pd.DataFrame(data)

# print out the DataFrame to verify
print(existing_df.head())

# load the data from your JSON file
with open(new_data_json_path, 'r') as f:
    new_data = json.load(f)

# convert the data into a pandas DataFrame
new_df = pd.DataFrame(new_data)

# print out the DataFrame to verify
print(new_df.head())
# Out:
#                                  id  \
# 0  https://openalex.org/W1002897494
# 1  https://openalex.org/W1010274275
# 2  https://openalex.org/W1012054217
# 3   https://openalex.org/W101897731
# 4  https://openalex.org/W1023696101
#
#                                             abstract  \
# 0  Abstract Carbon Capture and Storage is develop...
# 1  Searching for efficient solid sorbents for CO2...
# 2  The gaseous carbon dioxide incorporation react...
# 3                                               None
# 4  This paper presents a model to perform energy ...
#
#                                              authors  citationCount  \
# 0  [[https://openalex.org/A5054450376, Yasin Ghol...             10
# 1  [[https://openalex.org/A5005055697, Guoping Ga...             38
# 2  [[https://openalex.org/A5044055674, Chika Haya...             21
# 3  [[https://openalex.org/A5030437606, Teng Ben],...              1
# 4  [[https://openalex.org/A5067189491, Arun Verma...             20
#
#    citationCount_normalized  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
#                                            citations classification_ids  \
# 0  [https://openalex.org/W1753239825, https://ope...               None
# 1  [https://openalex.org/W1966750682, https://ope...               None
# 2  [https://openalex.org/W1973556473, https://ope...               None
# 3  [https://openalex.org/W656376090, https://open...               None
# 4  [https://openalex.org/W1965513514, https://ope...               None
#
#                                             concepts  \
# 0  [{'id': 'https://openalex.org/C10899652', 'wik...
# 1  [{'id': 'https://openalex.org/C162862793', 'wi...
# 2  [{'id': 'https://openalex.org/C185592680', 'wi...
# 3  [{'id': 'https://openalex.org/C150394285', 'wi...
# 4  [{'id': 'https://openalex.org/C194439259', 'wi...
#
#                                                doi embedding  ...  language  \
# 0     https://doi.org/10.1016/j.molliq.2015.06.060      None  ...        en
# 1  https://doi.org/10.1016/j.commatsci.2015.06.005      None  ...        en
# 2            https://doi.org/10.1246/bcsj.20150043      None  ...        en
# 3      https://doi.org/10.1007/978-3-642-54646-4_4      None  ...        en
# 4   https://doi.org/10.1016/j.ijhydene.2015.06.149      None  ...        en
#
#                             paperId publication_date relevance_score  text  \
# 0  https://openalex.org/W1002897494       2015-11-01       21.742895  None
# 1  https://openalex.org/W1010274275       2015-10-01       21.940535  None
# 2  https://openalex.org/W1012054217       2015-06-15       21.467160  None
# 3   https://openalex.org/W101897731       2014-01-01       22.707438  None
# 4  https://openalex.org/W1023696101       2015-09-01       17.861244  None
#
#                                                title  \
# 0  Suggesting a numerical pressure-decay method f...
# 1  Modelling CO 2 adsorption and separation on ex...
# 2  Cobalt-Catalyzed Reductive Carboxylation of α,...
# 3  Carbon Dioxide Capture in Porous Aromatic Fram...
# 4  Development of a process simulation model for ...
#
#                                                url   x   y  year
# 0     https://doi.org/10.1016/j.molliq.2015.06.060 NaN NaN  2015
# 1  https://doi.org/10.1016/j.commatsci.2015.06.005 NaN NaN  2015
# 2            https://doi.org/10.1246/bcsj.20150043 NaN NaN  2015
# 3      https://doi.org/10.1007/978-3-642-54646-4_4 NaN NaN  2014
# 4   https://doi.org/10.1016/j.ijhydene.2015.06.149 NaN NaN  2015
#
# [5 rows x 22 columns]
#                                  id  \
# 0  https://openalex.org/W2948440321
# 1  https://openalex.org/W2130861802
# 2  https://openalex.org/W2062396111
# 3  https://openalex.org/W2004704198
# 4  https://openalex.org/W1971632124
#
#                                            doi  \
# 0  https://doi.org/10.1016/j.enpol.2008.09.058
# 1  https://doi.org/10.1016/j.proci.2006.08.123
# 2           https://doi.org/10.1039/c2ee21152a
# 3  https://doi.org/10.1016/j.cherd.2011.01.028
# 4      https://doi.org/10.1126/science.1181637
#
#                                                title  isOpenAccess  \
# 0                         Carbon capture and storage         False
# 1            Combustion processes for carbon capture         False
# 2  Carbon capture with ionic liquids: overview an...         False
# 3  Recent developments on carbon capture and stor...         False
# 4                   Carbon Capture and Sequestration          True
#
#                                             abstract  \
# 0  Abstract Carbon capture and storage (CCS) cove...
# 1  A review of the technologies for coal-based po...
# 2  As an emerging carbon dioxide (CO2) capture te...
# 3  Abstract The Intergovernmental Panel on Climat...
# 4  Overwhelming scientific evidence shows that CO...
#
#                             paperId  \
# 0  https://openalex.org/W2948440321
# 1  https://openalex.org/W2130861802
# 2  https://openalex.org/W2062396111
# 3  https://openalex.org/W2004704198
# 4  https://openalex.org/W1971632124
#
#                                            url  \
# 0  https://doi.org/10.1016/j.enpol.2008.09.058
# 1  https://doi.org/10.1016/j.proci.2006.08.123
# 2           https://doi.org/10.1039/c2ee21152a
# 3  https://doi.org/10.1016/j.cherd.2011.01.028
# 4      https://doi.org/10.1126/science.1181637
#
#                                            citations  citationCount  \
# 0  [https://openalex.org/W90431621, https://opena...            766
# 1  [https://openalex.org/W18395829, https://opena...            523
# 2  [https://openalex.org/W91399062, https://opena...            688
# 3  [https://openalex.org/W1560140303, https://ope...            582
# 4                                                 []            429
#
#                                             concepts publication_date  \
# 0  [{'id': 'https://openalex.org/C2778379663', 'w...       2008-12-01
# 1  [{'id': 'https://openalex.org/C115033672', 'wi...       2007-01-01
# 2  [{'id': 'https://openalex.org/C154881586', 'wi...       2012-01-01
# 3  [{'id': 'https://openalex.org/C2778379663', 'w...       2011-09-01
# 4  [{'id': 'https://openalex.org/C518851703', 'wi...       2009-09-25
#
#    relevance_score language  year  \
# 0        2550.5002       en  2008
# 1        2074.8838       en  2007
# 2        1929.9143       en  2012
# 3        1890.0559       en  2011
# 4        1789.7405       en  2009
#
#                                              authors
# 0  [[https://openalex.org/A5076171257, Jon Gibbin...
# 1   [[https://openalex.org/A5037906929, Terry Wall]]
# 2  [[https://openalex.org/A5045790623, Xiangping ...
# 3  [[https://openalex.org/A5064215038, José C.M. ...
# 4   [[https://openalex.org/A5001967033, Steven Chu]]

# %%
print(existing_df.columns)
# Out:
# Index(['id', 'abstract', 'authors', 'citationCount',
#        'citationCount_normalized', 'citations', 'classification_ids',
#        'concepts', 'doi', 'embedding', 'isOpenAccess',
#        'keyword_classification_ids', 'language', 'paperId', 'publication_date',
#        'relevance_score', 'text', 'title', 'url', 'x', 'y', 'year'],
#       dtype='object')

# %%
print(new_df.columns)
new_df.iloc[124]
# Out:
# Index(['id', 'doi', 'title', 'isOpenAccess', 'abstract', 'paperId', 'url',
#        'citations', 'citationCount', 'concepts', 'publication_date',
#        'relevance_score', 'language', 'year', 'authors'],
#       dtype='object')
# id                                   https://openalex.org/W2091187815
# doi                                  https://doi.org/10.1039/c004561f
# title               Sustainability: the capacity of smokeless biom...
# isOpenAccess                                                    False
# abstract            Smokeless biomass pyrolysis for biochar and bi...
# paperId                              https://openalex.org/W2091187815
# url                                  https://doi.org/10.1039/c004561f
# citations           [https://openalex.org/W1648147279, https://ope...
# citationCount                                                     118
# concepts            [{'id': 'https://openalex.org/C56085101', 'wik...
# publication_date                                           2010-01-01
# relevance_score                                             698.29156
# language                                                           en
# year                                                             2010
# authors             [[https://openalex.org/A5008809812, James W. L...
# Name: 124, dtype: object

# %%
# Set 'id' as the index in both dataframes if not done already
existing_df.set_index('id', inplace=True)
new_df.set_index('id', inplace=True)

# Combine the two dataframes, updating the values in existing_df with the non-NA ones from new_df and adding new rows from new_df
combined_df = new_df.combine_first(existing_df)

# Reset the index
combined_df.reset_index(inplace=True)

# %%
combined_df[combined_df["embedding"].notnull()].head(10)
# Out:
#                                    id  \
# 9     https://openalex.org/W106711868
# 18   https://openalex.org/W1120477740
# 38   https://openalex.org/W1195955210
# 51    https://openalex.org/W136378602
# 69   https://openalex.org/W1480987708
# 72   https://openalex.org/W1483715699
# 76   https://openalex.org/W1488574179
# 78   https://openalex.org/W1488616880
# 89   https://openalex.org/W1503832382
# 101  https://openalex.org/W1510971620
#
#                                               abstract authors  citationCount  \
# 9    This article outlines the ongoing research, de...    None           1948
# 18   Gelatin methacryloyl (GelMA) hydrogels have be...    None           1570
# 38   The emerging trends in the combinatorial chemi...    None            815
# 51   ADVERTISEMENT RETURN TO ISSUEPREVArticleNEXTMe...    None            872
# 69                                                None    None            836
# 72                                                None    None           1003
# 76   The fundamental biophysical cause of stagnant ...    None            958
# 78                                                None    None           1199
# 89   Anthropogenically induced global climate chang...    None           2042
# 101  While many corporations and Information System...    None            835
#
#      citationCount_normalized  \
# 9                    7.246559
# 18                   4.870844
# 38                   0.125699
# 51                   0.483942
# 69                   0.257683
# 72                   1.307272
# 76                   1.024448
# 78                   2.539124
# 89                   7.837345
# 101                  0.251398
#
#                                              citations  \
# 9    https://api.openalex.org/works?filter=cites:W1...
# 18   https://api.openalex.org/works?filter=cites:W1...
# 38   https://api.openalex.org/works?filter=cites:W1...
# 51   https://api.openalex.org/works?filter=cites:W1...
# 69   https://api.openalex.org/works?filter=cites:W1...
# 72   https://api.openalex.org/works?filter=cites:W1...
# 76   https://api.openalex.org/works?filter=cites:W1...
# 78   https://api.openalex.org/works?filter=cites:W1...
# 89   https://api.openalex.org/works?filter=cites:W1...
# 101  https://api.openalex.org/works?filter=cites:W1...
#
#                                     classification_ids  \
# 9      [['microgrids, distributed generation', '7.3']]
# 18   [['synthesis, properties, biomedical applicati...
# 38   [['insoluble drug delivery strategies', '15.2'...
# 51   [['methanol electrooxidation, platinum-rutheni...
# 69   [['photoactivated γ-secretase inhibitors', '15...
# 72   [['olfactory system', '12.1'], ['sense of scen...
# 76   [['Soil Fertility, Hunger, Africa', '13.3'], [...
# 78   [['increasing shrub abundance, Arctic', '11.2'...
# 89   [['climate change impacts, coastal marine syst...
# 101  [['information systems', '19.3'], ['environmen...
#
#                                               concepts  \
# 9    [{'id': 'https://openalex.org/C2776784348', 'w...
# 18   [{'id': 'https://openalex.org/C108586683', 'wi...
# 38   [{'id': 'https://openalex.org/C2780035454', 'w...
# 51   [{'id': 'https://openalex.org/C2778805511', 'w...
# 69   [{'id': 'https://openalex.org/C175344181', 'wi...
# 72   [{'id': 'https://openalex.org/C137858568', 'wi...
# 76   [{'id': 'https://openalex.org/C518429986', 'wi...
# 78   [{'id': 'https://openalex.org/C125069764', 'wi...
# 89   [{'id': 'https://openalex.org/C132651083', 'wi...
# 101  [{'id': 'https://openalex.org/C191630685', 'wi...
#
#                                                    doi  \
# 9             https://doi.org/10.1109/mpae.2007.376583
# 18   https://doi.org/10.1016/j.biomaterials.2015.08...
# 38          https://doi.org/10.1016/j.apsb.2015.07.003
# 51                 https://doi.org/10.1021/j100148a030
# 69                    https://doi.org/10.1038/35015085
# 72                    https://doi.org/10.1038/35093026
# 76             https://doi.org/10.1126/science.1065256
# 78                    https://doi.org/10.1038/35079180
# 89    https://doi.org/10.1111/j.1461-0248.2005.00871.x
# 101                   https://doi.org/10.2307/20721413
#
#                                              embedding  ...  language  \
# 9    [-3.7157578468, 0.3801097274, 2.6234023571, 7....  ...      None
# 18   [1.3645195961, -6.1004862785, 2.5272161961, 2....  ...      None
# 38   [-2.5491518974, -6.3685898781, -0.6053708196, ...  ...      None
# 51   [-2.3224301338, -1.7931284904, -0.4194881916, ...  ...      None
# 69   [2.0554823875, -5.233109951, 3.2270386219, 4.6...  ...      None
# 72   [-1.0900194645, -3.8123064041, 2.0376121998, 1...  ...      None
# 76   [0.5130725503, -3.2843272686, 2.0291566849, 7....  ...      None
# 78   [-0.7954974174, -2.4829354286, 3.8367347717, 1...  ...      None
# 89   [0.1735337973, -2.6799008846, 5.51720047, 6.83...  ...      None
# 101  [4.1164665222, -3.0430104733, 0.9448026419, 5....  ...      None
#
#                               paperId publication_date relevance_score  \
# 9     https://openalex.org/W106711868             None             NaN
# 18   https://openalex.org/W1120477740             None             NaN
# 38   https://openalex.org/W1195955210             None             NaN
# 51    https://openalex.org/W136378602             None             NaN
# 69   https://openalex.org/W1480987708             None             NaN
# 72   https://openalex.org/W1483715699             None             NaN
# 76   https://openalex.org/W1488574179             None             NaN
# 78   https://openalex.org/W1488616880             None             NaN
# 89   https://openalex.org/W1503832382             None             NaN
# 101  https://openalex.org/W1510971620             None             NaN
#
#                                                   text  \
# 9    Title: Microgrids. Abstract: This article outl...
# 18   Title: Synthesis, properties, and biomedical a...
# 38   Title: Insoluble drug delivery strategies: rev...
# 51   Title: Methanol electrooxidation on well-chara...
# 69   Title: Photoactivated γ-secretase inhibitors d...
# 72   Title: How the olfactory system makes sense of...
# 76   Title: Soil Fertility and Hunger in Africa. Ab...
# 78    Title: Increasing shrub abundance in the Arctic.
# 89   Title: The impacts of climate change in coasta...
# 101  Title: Information Systems and Environmentally...
#
#                                                  title  \
# 9                                           Microgrids
# 18   Synthesis, properties, and biomedical applicat...
# 38   Insoluble drug delivery strategies: review of ...
# 51   Methanol electrooxidation on well-characterize...
# 69   Photoactivated γ-secretase inhibitors directed...
# 72      How the olfactory system makes sense of scents
# 76                 Soil Fertility and Hunger in Africa
# 78            Increasing shrub abundance in the Arctic
# 89   The impacts of climate change in coastal marin...
# 101  Information Systems and Environmentally Sustai...
#
#                                                    url          x          y  \
# 9             https://doi.org/10.1109/mpae.2007.376583  11.627406  15.733669
# 18   https://doi.org/10.1016/j.biomaterials.2015.08...  12.769749 -40.544907
# 38          https://doi.org/10.1016/j.apsb.2015.07.003   5.094404 -46.286049
# 51                 https://doi.org/10.1021/j100148a030  -0.587784 -13.101225
# 69                    https://doi.org/10.1038/35015085  42.791965  33.658840
# 72                    https://doi.org/10.1038/35093026  30.307610  29.472147
# 76             https://doi.org/10.1126/science.1065256 -16.841402  13.243733
# 78                    https://doi.org/10.1038/35079180  27.791452  33.308529
# 89    https://doi.org/10.1111/j.1461-0248.2005.00871.x -32.350948   8.865793
# 101                   https://doi.org/10.2307/20721413  -1.224144  34.546864
#
#      year
# 9    2007
# 18   2015
# 38   2015
# 51   1993
# 69   2000
# 72   2001
# 76   2002
# 78   2001
# 89   2006
# 101  2010
#
# [10 rows x 22 columns]

# %%
from datetime import date

# Get today's date
today = date.today()

# Format today's date as a string in the '23-06-03' format
date_string = today.strftime('%y-%m-%d')

combined_df.to_json(f'papers/{date_string}_{combined_df.shape[0]}_database_update.json', orient='records')

combined_df.to_json(f'papers/{date_string}_{combined_df.shape[0]}_database_update_readable.json', orient='records', indent=2)
